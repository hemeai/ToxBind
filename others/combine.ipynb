# %%
import os
import pandas as pd

# Function to get paths of PDB files from the 'Accepted' folder
def get_pdb_paths_from_accepted(base_path):
    pdb_paths = []
    
    # Iterate through each folder in the base path
    for folder_name in os.listdir(base_path):
        folder_path = os.path.join(base_path, folder_name)
        
        # Check if it's a directory
        if os.path.isdir(folder_path):
            # Define the path to the 'Accepted' folder
            accepted_folder_path = os.path.join(folder_path, 'Accepted')
            
            # Check if the 'Accepted' folder exists
            if os.path.exists(accepted_folder_path):
                # Iterate through files in the 'Accepted' folder
                for file_name in os.listdir(accepted_folder_path):
                    if file_name.endswith('.pdb'):
                        pdb_paths.append(os.path.join(accepted_folder_path, file_name))
    
    return pdb_paths

# Example usage
base_path = './../out/bindcraft/snake-venom-binder'
pdb_file_paths = get_pdb_paths_from_accepted(base_path)
print(pdb_file_paths)

# Example usage
# base_path = './../out/bindcraft/'
# final_design_stats_df = read_csv_from_folders(base_path)
# final_design_stats_df.head()
# final_design_stats_df.shape
# Out:
# ['./../out/bindcraft/snake-venom-binder/2502091148/Accepted/7z14_l88_s201849_mpnn4_model2.pdb', './../out/bindcraft/snake-venom-binder/2502091148/Accepted/7z14_l88_s201849_mpnn7_model2.pdb', './../out/bindcraft/snake-venom-binder/2501180951/Accepted/1yi5_l159_s712800_mpnn6_model1.pdb', './../out/bindcraft/snake-venom-binder/2501180951/Accepted/1yi5_l159_s712800_mpnn15_model1.pdb', './../out/bindcraft/snake-venom-binder/2501180951/Accepted/1yi5_l153_s269018_mpnn8_model2.pdb', './../out/bindcraft/snake-venom-binder/2502151901/Accepted/1yi5_l88_s642851_mpnn2_model1.pdb', './../out/bindcraft/snake-venom-binder/2502151901/Accepted/1yi5_l88_s642851_mpnn6_model2.pdb', './../out/bindcraft/snake-venom-binder/2501171452/Accepted/5nq4_l120_s808237_mpnn8_model2.pdb', './../out/bindcraft/snake-venom-binder/2501171452/Accepted/5nq4_l120_s808237_mpnn5_model2.pdb', './../out/bindcraft/snake-venom-binder/2502161339/Accepted/1yi5_l84_s615725_mpnn14_model2.pdb', './../out/bindcraft/snake-venom-binder/2502152311/Accepted/1yi5_l83_s980977_mpnn1_model2.pdb', './../out/bindcraft/snake-venom-binder/2502152311/Accepted/1yi5_l83_s980977_mpnn2_model2.pdb', './../out/bindcraft/snake-venom-binder/2501162231/Accepted/5nq4_l86_s533102_mpnn8_model1.pdb', './../out/bindcraft/snake-venom-binder/2501162231/Accepted/5nq4_l88_s194736_mpnn6_model2.pdb', './../out/bindcraft/snake-venom-binder/2501162231/Accepted/5nq4_l88_s194736_mpnn5_model2.pdb', './../out/bindcraft/snake-venom-binder/2501162231/Accepted/5nq4_l86_s533102_mpnn6_model1.pdb', './../out/bindcraft/snake-venom-binder/2501181208/Accepted/1yi5_l96_s23541_mpnn2_model2.pdb', './../out/bindcraft/snake-venom-binder/2501181208/Accepted/1yi5_l96_s23541_mpnn13_model1.pdb', './../
# ⠦ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# https://modal.com/apps/deepsatflow/main/ap-79ToVi1Qk8sTsENk8O1aIM
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/deepsatflow/main/ap-79ToVi1Qk8sTsENk8O1aIM
# ✓ Initialized. View run at
# https://modal.com/apps/deepsatflow/main/ap-vFoT4L9siiTUT1mUtOG2Hd
# ⠋ Initializing...
# ⠦ Creating objects...objects...
# └── ⠋ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── ⠸ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠸ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ⠼ Worker assigned... View app at
# ⠧ Running... View app at mUtOG2Hd
# ⠋ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# https://modal.com/apps/deepsatflow/main/ap-vFoT4L9siiTUT1mUtOG2Hd
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/deepsatflow/main/ap-vFoT4L9siiTUT1mUtOG2Hd
# ✓ Initialized. View run at
# https://modal.com/apps/deepsatflow/main/ap-W7roA98F354onivyCUqka3
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠦ Creating objects...
# └── ⠸ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── ⠦ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠴ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠴ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ⠴ Running... View app at
# ⠇ Running... View app at vyCUqka3
# ⠙ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ...
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# https://modal.com/apps/deepsatflow/main/ap-F2aslhDxS3RGE7vZwsh4XN
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/deepsatflow/main/ap-F2aslhDxS3RGE7vZwsh4XN
# ✓ Initialized. View run at
# https://modal.com/apps/deepsatflow/main/ap-98d404muGYmwh71Ty3q2My
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠦ Creating objects...
# └── ⠸ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠹ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠹ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ⠹ Running... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# https://modal.com/apps/deepsatflow/main/ap-98d404muGYmwh71Ty3q2My
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/deepsatflow/main/ap-98d404muGYmwh71Ty3q2My
# ✓ Initialized. View run at
# https://modal.com/apps/deepsatflow/main/ap-fzB89NNTbfxXFWWATaggy6
# ⠋ Initializing...
# ⠦ Creating objects...objects...
# └── ⠋ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── ⠸ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠸ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ⠹ Running... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# https://modal.com/apps/deepsatflow/main/ap-fzB89NNTbfxXFWWATaggy6
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/deepsatflow/main/ap-fzB89NNTbfxXFWWATaggy6
# ✓ Initialized. View run at
# https://modal.com/apps/deepsatflow/main/ap-iUd8OT5SlJF8JUph9MLgGF
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠦ Creating objects...
# └── ⠸ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠙ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ⠇ Worker assigned... View app at
# ⠙ Running... View app at ph9MLgGF
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# https://modal.com/apps/deepsatflow/main/ap-iUd8OT5SlJF8JUph9MLgGF
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at
# https://modal.com/apps/deepsatflow/main/ap-iUd8OT5SlJF8JUph9MLgGF
# ✓ Initialized. View run at
# https://modal.com/apps/deepsatflow/main/ap-zAEcr0Myln2ZDtoxzVDvgq
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# ⠦ Creating objects...
# └── ⠸ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── ⠦ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠸ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ⠹ Worker assigned... View app at
# ⠴ Running... View app at oxzVDvgq
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# https://modal.com/apps/deepsatflow/main/ap-zAEcr0Myln2ZDtoxzVDvgq
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/deepsatflow/main/ap-zAEcr0Myln2ZDtoxzVDvgq
# ✓ Initialized. View run at
# https://modal.com/apps/deepsatflow/main/ap-lulMO16dQlazb1NOQ1x0Dx
# ⠋ Initializing...
# ⠦ Creating objects...objects...
# └── ⠋ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── ⠸ Creating mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# ⠴ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# ⠦ Creating objects...
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/satishgaurav/Documents/extra/Hemeai/snake-venom-binder/others/modal_p
# │   db2png.py
# └── 🔨 Created function pdb2png.
# ⠹ Worker assigned... View app at
# ⠴ Running... View app at NOQ1x0Dx
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# https://modal.com/apps/deepsatflow/main/ap-lulMO16dQlazb1NOQ1x0Dx
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/deepsatflow/main/ap-lulMO16dQlazb1NOQ1x0Dx
